# %%
import time
import sys
import platform
import os
import pandas as pd
import json

from selenium import webdriver
from selenium.common.exceptions import TimeoutException
from selenium.webdriver.chrome.options import Options
from selenium.webdriver.common.by import By
from selenium.webdriver.support import expected_conditions as EC
from selenium.webdriver.support.ui import WebDriverWait


driver = None

def load_driver(url):
    """ Logging into our own profile """

    try:
        global driver

        options = Options()

        #  Code to disable notifications pop up of Chrome Browser
        options.add_argument("--disable-notifications")
        options.add_argument("--disable-infobars")
        options.add_argument("--mute-audio")
        # options.add_argument("headless")

        try:
            platform_ = platform.system().lower()
            print(platform_)
            if platform_ in ['linux', 'darwin']:
                print(webdriver.Chrome(executable_path="./chromedriver", options=options))
                driver = webdriver.Chrome(executable_path="./chromedriver", options=options)
            else:
                driver = webdriver.Chrome(executable_path="./chromedriver.exe", options=options)
        except:
            print("Kindly replace the Chrome Web Driver with the latest one from"
                  "http://chromedriver.chromium.org/downloads"
                  "\nYour OS: {}".format(platform_)
                 )
            exit()

        driver.get(url)
        driver.maximize_window()

    except Exception as e:
        print("There's some error in log in.")
        print(sys.exc_info()[0])
        print(e)
        exit()

# %%
def big_data_glosary():
    url = "https://bigdata-madesimple.com/big-data-a-to-zz-a-glossary-of-big-data-terminology/"
    load_driver(url)
    words = []
    descriptions = []
    url_word = []
    url_attachment = []
    word = driver.find_elements_by_xpath('(//div[contains(@class,"entry-content")]//h3//strong)')
    print(len(word))
    description = driver.find_elements_by_xpath('//div[contains(@class,"entry-content")]/p')
    for i in range(len(word)-1):
        if(i >=11):
            words.append(word[i+1].text)  
        else:
            words.append(word[i].text)   
        print('Word:',words[-1])
        descriptions.append(description[i+1].text)  
        url_word.append( driver.current_url)
        url_attachment.append([])
    
    return words,descriptions,url_word,url_attachment

# %%
def machine_learning_glosary():
    url = 'https://www.analyticsvidhya.com/glossary-of-common-statistics-and-machine-learning-terms/'
    load_driver(url)

    time.sleep(3)
    words = []
    descriptions = []
    url_word = []
    url_attachment = []
    tables =driver.find_elements_by_xpath('//div[contains(@class,"su-table")]')
    print('Tablas: ', len(tables))
    description = driver.find_elements_by_xpath('//div[contains(@class,"entry-content")]/p')
    for i in range(1,len(tables)):
        sub_tables = driver.find_elements_by_xpath('//div[contains(@class,"su-table")]['+str(i)+']/table')
        print('Sub-Tablas: ', len(sub_tables))
        for j in range(1,len(sub_tables)+1):
                list_words = driver.find_elements_by_xpath('//div[contains(@class,"su-table")]['+str(i)+']/table['+str(j)+']/tbody/tr')
                print('Lista palabras: ', len(list_words))
                for k in range(2,len(list_words)+1):
                    """Word"""
                    row =  driver.find_elements_by_xpath('//div[contains(@class,"su-table")]['+str(i)+']/table['+str(j)+']/tbody/tr['+str(k)+']/td')
                    word = row[0].text
                    words.append(word)
                    description = row[1].text
                    descriptions.append(description)               
                    print('Word:',word)
                    
                    """Attachments_url"""
                    
                    attachments = driver.find_elements_by_xpath('//div[contains(@class,"su-table")]['+str(i)+']/table['+str(j)+']/tbody/tr['+str(k)+']/td//img')
                    attachments_url = []
                    for attach in attachments:
                        attachments_url.append(attach.get_attribute("src")) 
                    
                    url_attachment.append(attachments_url)
                    url_word.append( driver.current_url)
                
    return words,descriptions,url_word,url_attachment

# %%
words_2,descriptions_2,url_word_2,url_attachment_2 = big_data_glosary()
words_1,descriptions_1,url_word_1,url_attachment_1 = machine_learning_glosary()
# Out:
# darwin
# <selenium.webdriver.chrome.webdriver.WebDriver (session="e1b8274f6ecd478e89fa16a91324af01")>
# 176
# Word: ACID test
# Word: Aggregation
# Word: Algorithm
# Word: Anonymization
# Word: Artificial Intelligence
# Word: Automatic identification and capture (AIDC)
# Word: Avro
# Word: Behavioral analytics
# Word: Big Data Scientist
# Word: Business Intelligence (BI)
# Word: Cascading
# Word: Call Detail Record (CDR) analysis
# Word: Cassandra
# Word: Cell phone data
# Word: Clickstream Analytics
# Word: Classification analysis
# Word: Cloud computing
# Word: Clustering analysis
# Word: Cold data storage
# Word: Comparative analysis
# Word: Chukwa
# Word: Clojure
# Word: Cloud
# Word: Columnar database or column-oriented database
# Word: Comparators
# Word: Complex event processing (CEP)
# Word: Confabulation
# Word: Cross-channel analytics
# Word: Data access
# Word: Dashboard
# Word: Data aggregation
# Word: Data architecture and design
# Word: Database
# Word: Database administrator (DBA)
# Word: Database as a service (DaaS)
# Word: Database management system (DBMS)
# Word: Data center
# Word: Data cleansing
# Word: Data collection
# Word: Data custodian
# Word: Data-directed decision making
# Word: Data exhaust
# Word: Data feed
# Word: Data governance
# Word: Data integration
# Word: Data integrity
# Word: Data mart
# Word: Data migration
# Word: Data mining
# Word: Data model, data modeling
# Word: Data point
# Word: Data profiling
# Word: Data quality
# Word: Data replication
# Word: Data repository
# Word: Data science
# Word: Data scientist
# Word: Data security
# Word: Data set
# Word: Data source
# Word: Data steward
# Word: Data structure
# Word: Data visualization
# Word: Data warehouse
# Word: De-identification
# Word: Demographic data
# Word: Deep Thunder
# Word: Distributed cache
# Word: Distributed object
# Word: Distributed processing
# Word: Distributed File System
# Word: Document Store Databases
# Word: Document management
# Word: Drill
# Word: Elasticsearch
# Word: Event analytics
# Word: Exabyte
# Word: External data
# Word: Extract, transform, and load (ETL)
# Word: Exploratory analysis
# Word: Failover
# Word: Flume
# Word: Grid computing
# Word: Graph Databases
# Word: Hadoop
# Word: Hama
# Word: HANA
# Word: HBase
# Word: HCatalog
# Word: HDFS (Hadoop Distributed File System)
# Word: Hive
# Word: Hue
# Word: Impala
# Word: In-database analytics
# Word: In-memory database
# Word: In-memory data grid (IMDG)
# Word: Internet of Things
# Word: Kafka
# Word: Key Value Stores
# Word: KeyValue Databases
# Word: Latency
# Word: Linked data
# Word: Load balancing
# Word: Location analytics
# Word: Location data
# Word: Log file
# Word: Machine-generated data
# Word: Machine2Machine data
# Word: Machine learning
# Word: MapReduce
# Word: Mashup
# Word: Mahout
# Word: Metadata
# Word: MongoDB
# Word: MPP database
# Word: Multi-Dimensional Databases
# Word: MultiValue Databases
# Word: Network analysis
# Word: NewSQL
# Word: NoSQL
# Word: Object Databases
# Word: Object-based Image Analysis
# Word: Online analytical processing (OLAP)
# Word: Online transactional processing (OLTP)
# Word: OpenDremel
# Word: Open Data Center Alliance (ODCA)
# Word: Operational data store (ODS)
# Word: Oozie
# Word: Parallel data analysis
# Word: Parallel method invocation (PMI)
# Word: Parallel processing
# Word: Parallel query
# Word: Pattern recognition
# Word: Pentaho
# Word: Petabyte
# Word: Pig
# Word: Predictive analytics
# Word: Predictive modeling
# Word: Public data
# Word: Query
# Word: Query analysis
# Word: R
# Word: Re-identification
# Word: Real-time data
# Word: Recommendation engine
# Word: Reference data
# Word: Risk analysis
# Word: Root-cause analysis
# Word: Routing analysis
# Word: Scalability
# Word: Schema
# Word: Search data
# Word: Semi-structured data
# Word: Sentiment analysis
# Word: Server
# Word: Spatial analysis
# Word: SQL
# Word: Sqoop
# Word: Storm
# Word: Software as a service (SaaS)
# Word: Storage
# Word: Storm
# Word: Structured data
# Word: Structured Query Language (SQL)
# Word: Text analytics
# Word: Transactional data
# Word: Thrift
# Word: Unstructured data
# Word: Value
# Word: Volume
# Word: Visualization
# Word: WebHDFS Apache Hadoop
# Word: Weather data
# Word: XML Databases
# Word: ZooKeeper
# darwin
# <selenium.webdriver.chrome.webdriver.WebDriver (session="0c947c5c97bf5cb2e4e4b4341d5ef6ef")>
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~/anaconda3/envs/WebScraping/lib/python3.7/site-packages/urllib3/connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     376             try:  # Python 2.7, use buffering of HTTP responses
# --> 377                 httplib_response = conn.getresponse(buffering=True)
#     378             except TypeError:  # Python 3
#
# TypeError: getresponse() got an unexpected keyword argument 'buffering'
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-64-735bc4d0c348> in <module>
#       1 words_2,descriptions_2,url_word_2,url_attachment_2 = big_data_glosary()
# ----> 2 words_1,descriptions_1,url_word_1,url_attachment_1 = machine_learning_glosary()
#
# <ipython-input-63-4de42e50de32> in machine_learning_glosary()
#       1 def machine_learning_glosary():
#       2     url = 'https://www.analyticsvidhya.com/glossary-of-common-statistics-and-machine-learning-terms/'
# ----> 3     load_driver(url)
#       4
#       5     time.sleep(3)
#
# <ipython-input-5-310587bcc7cf> in load_driver(url)
#      45             exit()
#      46
# ---> 47         driver.get(url)
#      48         driver.maximize_window()
#      49
#
# ~/anaconda3/envs/WebScraping/lib/python3.7/site-packages/selenium/webdriver/remote/webdriver.py in get(self, url)
#     331         Loads a web page in the current browser session.
#     332         """
# --> 333         self.execute(Command.GET, {'url': url})
#     334
#     335     @property
#
# ~/anaconda3/envs/WebScraping/lib/python3.7/site-packages/selenium/webdriver/remote/webdriver.py in execute(self, driver_command, params)
#     317
#     318         params = self._wrap_value(params)
# --> 319         response = self.command_executor.execute(driver_command, params)
#     320         if response:
#     321             self.error_handler.check_response(response)
#
# ~/anaconda3/envs/WebScraping/lib/python3.7/site-packages/selenium/webdriver/remote/remote_connection.py in execute(self, command, params)
#     372         data = utils.dump_json(params)
#     373         url = '%s%s' % (self._url, path)
# --> 374         return self._request(command_info[0], url, body=data)
#     375
#     376     def _request(self, method, url, body=None):
#
# ~/anaconda3/envs/WebScraping/lib/python3.7/site-packages/selenium/webdriver/remote/remote_connection.py in _request(self, method, url, body)
#     395
#     396         if self.keep_alive:
# --> 397             resp = self._conn.request(method, url, body=body, headers=headers)
#     398
#     399             statuscode = resp.status
#
# ~/anaconda3/envs/WebScraping/lib/python3.7/site-packages/urllib3/request.py in request(self, method, url, fields, headers, **urlopen_kw)
#      70             return self.request_encode_body(method, url, fields=fields,
#      71                                             headers=headers,
# ---> 72                                             **urlopen_kw)
#      73
#      74     def request_encode_url(self, method, url, fields=None, headers=None,
#
# ~/anaconda3/envs/WebScraping/lib/python3.7/site-packages/urllib3/request.py in request_encode_body(self, method, url, fields, headers, encode_multipart, multipart_boundary, **urlopen_kw)
#     148         extra_kw.update(urlopen_kw)
#     149
# --> 150         return self.urlopen(method, url, **extra_kw)
#
# ~/anaconda3/envs/WebScraping/lib/python3.7/site-packages/urllib3/poolmanager.py in urlopen(self, method, url, redirect, **kw)
#     321             response = conn.urlopen(method, url, **kw)
#     322         else:
# --> 323             response = conn.urlopen(method, u.request_uri, **kw)
#     324
#     325         redirect_location = redirect and response.get_redirect_location()
#
# ~/anaconda3/envs/WebScraping/lib/python3.7/site-packages/urllib3/connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     598                                                   timeout=timeout_obj,
#     599                                                   body=body, headers=headers,
# --> 600                                                   chunked=chunked)
#     601
#     602             # If we're going to release the connection in ``finally:``, then
#
# ~/anaconda3/envs/WebScraping/lib/python3.7/site-packages/urllib3/connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     378             except TypeError:  # Python 3
#     379                 try:
# --> 380                     httplib_response = conn.getresponse()
#     381                 except Exception as e:
#     382                     # Remove the TypeError from the exception chain in Python 3;
#
# ~/anaconda3/envs/WebScraping/lib/python3.7/http/client.py in getresponse(self)
#    1319         try:
#    1320             try:
# -> 1321                 response.begin()
#    1322             except ConnectionError:
#    1323                 self.close()
#
# ~/anaconda3/envs/WebScraping/lib/python3.7/http/client.py in begin(self)
#     294         # read until we get a non-100 response
#     295         while True:
# --> 296             version, status, reason = self._read_status()
#     297             if status != CONTINUE:
#     298                 break
#
# ~/anaconda3/envs/WebScraping/lib/python3.7/http/client.py in _read_status(self)
#     255
#     256     def _read_status(self):
# --> 257         line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     258         if len(line) > _MAXLINE:
#     259             raise LineTooLong("status line")
#
# ~/anaconda3/envs/WebScraping/lib/python3.7/socket.py in readinto(self, b)
#     587         while True:
#     588             try:
# --> 589                 return self._sock.recv_into(b)
#     590             except timeout:
#     591                 self._timeout_occurred = True
#
# KeyboardInterrupt:

# %%
words_final = words_2
descriptions_final = descriptions_2
url_word_final = url_word_2
url_attachment_final = url_attachment_2
json_total = {}
for x in range(len(words_1)):
    words_final.append(words_1[x])
    descriptions_final.append(descriptions_1[x])
    url_word_final.append(url_word_1[x])
    url_attachment_final.append(url_attachment_1[x])

# %%
for x in range(len(words_final)):
    json_d = {'Word':words_final[x],'Description':descriptions_final[x],'Url':url_word_final[x],'Attachment_Url':url_attachment_final[x]}
    json_total[x] = json_d
    json_total.update(json_d)
with open('../datasets/glossary_faq.json', 'w') as outfile:
    json.dump(json_total, outfile)
